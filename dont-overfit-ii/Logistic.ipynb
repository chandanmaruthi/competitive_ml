# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.metrics import roc_auc_score, confusion_matrix, log_loss, accuracy_score
from sklearn.preprocessing import LabelEncoder, RobustScaler, KBinsDiscretizer, PolynomialFeatures
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import RFE
from lightgbm import LGBMClassifier
from category_encoders import OneHotEncoder
from sklearn.model_selection import cross_val_predict, RepeatedStratifiedKFold, GridSearchCV, StratifiedKFold
from warnings import filterwarnings
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn import svm
import os
import matplotlib.pyplot as plt
import seaborn as sns
import gc
import time
from datetime import datetime
filterwarnings('ignore')

# %%
# Load data
do_sample = False
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
print("train data shape", train.shape)
print("test data shape", test.shape)
# Out:
# train data shape (250, 302)
# test data shape (19750, 301)

# %%
train_input = train.drop(['id','target'],axis = 1)
test_input  = test.drop(['id'],axis = 1)
train_cols = train_input.columns
test_cols = test_input.columns

train_labels = train['target']

#app_train = pd.get_dummies(train_input)
#app_test = pd.get_dummies(test_input)

#imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
#imp_mean.fit(app_train)
#train_imputed = imp_mean.transform(app_train)
#test_imputed = imp_mean.transform(app_test)

scaler = RobustScaler()
scaler.fit(train_input)
train_imputed = scaler.transform(train_input)
test_imputed = scaler.transform(test_input)
train_df = pd.DataFrame(train_imputed, columns = train_cols)
test_df = pd.DataFrame(test_imputed, columns = test_cols)

# %%
poly = PolynomialFeatures()
train_df = poly.fit_transform(train_df)
test_df = poly.fit_transform(test_df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-aff41f5e3ff6> in <module>
#       1 poly = PolynomialFeatures()
#       2 train_df = poly.fit_transform(train_df)
# ----> 3 test_df = poly.fit_transform(test_df)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     462         if y is None:
#     463             # fit method of arity 1 (unsupervised transformation)
# --> 464             return self.fit(X, **fit_params).transform(X)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py in transform(self, X)
#    1504             XP = sparse.hstack(columns, dtype=X.dtype).tocsc()
#    1505         else:
# -> 1506             XP = np.empty((n_samples, self.n_output_features_), dtype=X.dtype)
#    1507             for i, comb in enumerate(combinations):
#    1508                 XP[:, i] = X[:, comb].prod(1)
#
# MemoryError:

# %%
rfe = RFE(LogisticRegression(n_jobs=-1, penalty='l1', C=0.2, class_weight='balanced', solver='saga'),n_features_to_select=200)
rfe = rfe.fit(train_df, train_labels)

# %%
predictions = rfe.predict_proba(test_df)[:,1]

# %%
predictions
# Out:
# array([0.74124924, 0.5429478 , 0.63459652, ..., 0.37093393, 0.9215228 ,
#        0.23987409])

# %%
def cross_validation(model_, train_, target_):
    
    clfs = []
    folds = RepeatedStratifiedKFold(n_splits = 5, n_repeats = 20, random_state = 42)
    
    valid_pred = pd.DataFrame(index = train_.index)
    
    # Cross-validation cycle
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(target_, target_)):
        print('--- Fold {} started at {}'.format(n_fold, time.ctime()))
        
        train_x, train_y = train_.iloc[train_idx], target_.iloc[train_idx]
        valid_x, valid_y = train_.iloc[valid_idx], target_.iloc[valid_idx]
        
        
        model_.fit(train_x, train_y)
    
        

        predict = model_.predict_proba(valid_x)[:, 1]
    
        tn, fp, fn, tp = confusion_matrix(valid_y, (predict >= .5) * 1).ravel()
        auc = roc_auc_score(valid_y, predict)
        acc = accuracy_score(valid_y, (predict >= .5) * 1)
        loss = log_loss(valid_y, predict)
        print('TN =', tn, 'FN =', fn, 'FP =', fp, 'TP =', tp)
        print('AUC = ', auc, 'Loss =', loss, 'Acc =', acc)
        
        #valid_pred[n_fold] = pd.Series(predict, index = valid_x.index)
        if auc > 0.8:
            clfs.append(model_)
        del train_x, train_y, valid_x, valid_y, predict
        gc.collect()

    return clfs

# %%
logreg = LogisticRegression(n_jobs=-1, penalty='l1', C=0.2, class_weight='balanced', solver='saga')

# %%
models = cross_validation(logreg, train_df, train_labels)
# Out:
# --- Fold 0 started at Thu Apr 25 11:43:09 2019
# TN = 11 FN = 6 FP = 7 TP = 26
# AUC =  0.8194444444444444 Loss = 0.5024640675658794 Acc = 0.74
# --- Fold 1 started at Thu Apr 25 11:43:09 2019
# TN = 13 FN = 12 FP = 5 TP = 20
# AUC =  0.7864583333333333 Loss = 0.5814435029083824 Acc = 0.66
# --- Fold 2 started at Thu Apr 25 11:43:09 2019
# TN = 11 FN = 7 FP = 7 TP = 25
# AUC =  0.8194444444444444 Loss = 0.5197987969722148 Acc = 0.72
# --- Fold 3 started at Thu Apr 25 11:43:09 2019
# TN = 8 FN = 6 FP = 10 TP = 26
# AUC =  0.7708333333333333 Loss = 0.536646283607311 Acc = 0.68
# --- Fold 4 started at Thu Apr 25 11:43:09 2019
# TN = 8 FN = 4 FP = 10 TP = 28
# AUC =  0.7725694444444444 Loss = 0.529391744026143 Acc = 0.72
# --- Fold 5 started at Thu Apr 25 11:43:10 2019
# TN = 11 FN = 9 FP = 7 TP = 23
# AUC =  0.7690972222222222 Loss = 0.568784872406496 Acc = 0.68
# --- Fold 6 started at Thu Apr 25 11:43:10 2019
# TN = 10 FN = 8 FP = 8 TP = 24
# AUC =  0.717013888888889 Loss = 0.6096012264825561 Acc = 0.68
# --- Fold 7 started at Thu Apr 25 11:43:10 2019
# TN = 10 FN = 10 FP = 8 TP = 22
# AUC =  0.6631944444444444 Loss = 0.6177365664079951 Acc = 0.64
# --- Fold 8 started at Thu Apr 25 11:43:10 2019
# TN = 11 FN = 8 FP = 7 TP = 24
# AUC =  0.7881944444444444 Loss = 0.5151665694764954 Acc = 0.7
# --- Fold 9 started at Thu Apr 25 11:43:11 2019
# TN = 13 FN = 8 FP = 5 TP = 24
# AUC =  0.7690972222222222 Loss = 0.5584657555735953 Acc = 0.74
# --- Fold 10 started at Thu Apr 25 11:43:11 2019
# TN = 11 FN = 7 FP = 7 TP = 25
# AUC =  0.7881944444444444 Loss = 0.5365903016529064 Acc = 0.72
# --- Fold 11 started at Thu Apr 25 11:43:11 2019
# TN = 7 FN = 10 FP = 11 TP = 22
# AUC =  0.6753472222222222 Loss = 0.6053194871451405 Acc = 0.58
# --- Fold 12 started at Thu Apr 25 11:43:11 2019
# TN = 15 FN = 7 FP = 3 TP = 25
# AUC =  0.8142361111111112 Loss = 0.5159939479139537 Acc = 0.8
# --- Fold 13 started at Thu Apr 25 11:43:12 2019
# TN = 11 FN = 4 FP = 7 TP = 28
# AUC =  0.751736111111111 Loss = 0.5637318735708395 Acc = 0.78
# --- Fold 14 started at Thu Apr 25 11:43:12 2019
# TN = 12 FN = 8 FP = 6 TP = 24
# AUC =  0.8559027777777778 Loss = 0.48633278870328894 Acc = 0.72
# --- Fold 15 started at Thu Apr 25 11:43:12 2019
# TN = 10 FN = 6 FP = 8 TP = 26
# AUC =  0.7777777777777778 Loss = 0.5487290989427338 Acc = 0.72
# --- Fold 16 started at Thu Apr 25 11:43:12 2019
# TN = 15 FN = 6 FP = 3 TP = 26
# AUC =  0.8680555555555556 Loss = 0.47822295023295686 Acc = 0.82
# --- Fold 17 started at Thu Apr 25 11:43:12 2019
# TN = 12 FN = 5 FP = 6 TP = 27
# AUC =  0.8489583333333334 Loss = 0.48195543348378783 Acc = 0.78
# --- Fold 18 started at Thu Apr 25 11:43:13 2019
# TN = 16 FN = 8 FP = 2 TP = 24
# AUC =  0.8680555555555556 Loss = 0.5222965099097013 Acc = 0.8
# --- Fold 19 started at Thu Apr 25 11:43:13 2019
# TN = 12 FN = 6 FP = 6 TP = 26
# AUC =  0.8055555555555556 Loss = 0.5477181537385001 Acc = 0.76
# --- Fold 20 started at Thu Apr 25 11:43:13 2019
# TN = 12 FN = 7 FP = 6 TP = 25
# AUC =  0.8229166666666667 Loss = 0.4939263811773309 Acc = 0.74
# --- Fold 21 started at Thu Apr 25 11:43:13 2019
# TN = 10 FN = 8 FP = 8 TP = 24
# AUC =  0.795138888888889 Loss = 0.5052173924096345 Acc = 0.68
# --- Fold 22 started at Thu Apr 25 11:43:13 2019
# TN = 11 FN = 8 FP = 7 TP = 24
# AUC =  0.8194444444444444 Loss = 0.5216503696638171 Acc = 0.7
# --- Fold 23 started at Thu Apr 25 11:43:14 2019
# TN = 11 FN = 11 FP = 7 TP = 21
# AUC =  0.7829861111111112 Loss = 0.5312982066700924 Acc = 0.64
# --- Fold 24 started at Thu Apr 25 11:43:14 2019
# TN = 14 FN = 11 FP = 4 TP = 21
# AUC =  0.7569444444444444 Loss = 0.5940607375932965 Acc = 0.7
# --- Fold 25 started at Thu Apr 25 11:43:14 2019
# TN = 11 FN = 5 FP = 7 TP = 27
# AUC =  0.7934027777777778 Loss = 0.5381188534655655 Acc = 0.76
# --- Fold 26 started at Thu Apr 25 11:43:14 2019
# TN = 12 FN = 7 FP = 6 TP = 25
# AUC =  0.7743055555555556 Loss = 0.562594477641234 Acc = 0.74
# --- Fold 27 started at Thu Apr 25 11:43:14 2019
# TN = 13 FN = 6 FP = 5 TP = 26
# AUC =  0.8454861111111112 Loss = 0.496716122291393 Acc = 0.78
# --- Fold 28 started at Thu Apr 25 11:43:15 2019
# TN = 11 FN = 3 FP = 7 TP = 29
# AUC =  0.8819444444444444 Loss = 0.44468295581117806 Acc = 0.8
# --- Fold 29 started at Thu Apr 25 11:43:15 2019
# TN = 11 FN = 5 FP = 7 TP = 27
# AUC =  0.7881944444444445 Loss = 0.5583384428627184 Acc = 0.76
# --- Fold 30 started at Thu Apr 25 11:43:15 2019
# TN = 13 FN = 8 FP = 5 TP = 24
# AUC =  0.7743055555555556 Loss = 0.5720156380854372 Acc = 0.74
# --- Fold 31 started at Thu Apr 25 11:43:15 2019
# TN = 9 FN = 4 FP = 9 TP = 28
# AUC =  0.7604166666666667 Loss = 0.5475083869028332 Acc = 0.74
# --- Fold 32 started at Thu Apr 25 11:43:16 2019
# TN = 11 FN = 7 FP = 7 TP = 25
# AUC =  0.7829861111111112 Loss = 0.5289543547845632 Acc = 0.72
# --- Fold 33 started at Thu Apr 25 11:43:16 2019
# TN = 13 FN = 7 FP = 5 TP = 25
# AUC =  0.828125 Loss = 0.5177785909570827 Acc = 0.76
# --- Fold 34 started at Thu Apr 25 11:43:16 2019
# TN = 14 FN = 9 FP = 4 TP = 23
# AUC =  0.8697916666666667 Loss = 0.4585552138828298 Acc = 0.74
# --- Fold 35 started at Thu Apr 25 11:43:16 2019
# TN = 14 FN = 6 FP = 4 TP = 26
# AUC =  0.8871527777777778 Loss = 0.46557489401567087 Acc = 0.8
# --- Fold 36 started at Thu Apr 25 11:43:16 2019
# TN = 16 FN = 10 FP = 2 TP = 22
# AUC =  0.8732638888888888 Loss = 0.4614098808615414 Acc = 0.76
# --- Fold 37 started at Thu Apr 25 11:43:17 2019
# TN = 10 FN = 5 FP = 8 TP = 27
# AUC =  0.7777777777777778 Loss = 0.5267389803597479 Acc = 0.74
# --- Fold 38 started at Thu Apr 25 11:43:17 2019
# TN = 8 FN = 5 FP = 10 TP = 27
# AUC =  0.7118055555555556 Loss = 0.5945322695125427 Acc = 0.7
# --- Fold 39 started at Thu Apr 25 11:43:17 2019
# TN = 11 FN = 10 FP = 7 TP = 22
# AUC =  0.7690972222222222 Loss = 0.5562053759153232 Acc = 0.66
# --- Fold 40 started at Thu Apr 25 11:43:17 2019
# TN = 11 FN = 8 FP = 7 TP = 24
# AUC =  0.8020833333333333 Loss = 0.5070142013508635 Acc = 0.7
# --- Fold 41 started at Thu Apr 25 11:43:17 2019
# TN = 11 FN = 10 FP = 7 TP = 22
# AUC =  0.6996527777777777 Loss = 0.6476188300184081 Acc = 0.66
# --- Fold 42 started at Thu Apr 25 11:43:18 2019
# TN = 12 FN = 8 FP = 6 TP = 24
# AUC =  0.7708333333333333 Loss = 0.5723892408350051 Acc = 0.72
# --- Fold 43 started at Thu Apr 25 11:43:18 2019
# TN = 10 FN = 10 FP = 8 TP = 22
# AUC =  0.7378472222222222 Loss = 0.5680483687591937 Acc = 0.64
# --- Fold 44 started at Thu Apr 25 11:43:18 2019
# TN = 16 FN = 8 FP = 2 TP = 24
# AUC =  0.8697916666666667 Loss = 0.471104205004368 Acc = 0.8
# --- Fold 45 started at Thu Apr 25 11:43:18 2019
# TN = 10 FN = 8 FP = 8 TP = 24
# AUC =  0.7447916666666666 Loss = 0.5694458143435436 Acc = 0.68
# --- Fold 46 started at Thu Apr 25 11:43:18 2019
# TN = 11 FN = 8 FP = 7 TP = 24
# AUC =  0.689236111111111 Loss = 0.656776776988158 Acc = 0.7
# --- Fold 47 started at Thu Apr 25 11:43:19 2019
# TN = 12 FN = 9 FP = 6 TP = 23
# AUC =  0.7881944444444445 Loss = 0.5264229529406869 Acc = 0.7
# --- Fold 48 started at Thu Apr 25 11:43:19 2019
# TN = 15 FN = 6 FP = 3 TP = 26
# AUC =  0.8940972222222222 Loss = 0.4652428013303975 Acc = 0.82
# --- Fold 49 started at Thu Apr 25 11:43:19 2019
# TN = 8 FN = 7 FP = 10 TP = 25
# AUC =  0.6614583333333333 Loss = 0.6124323386339073 Acc = 0.66
# --- Fold 50 started at Thu Apr 25 11:43:19 2019
# TN = 11 FN = 8 FP = 7 TP = 24
# AUC =  0.7777777777777778 Loss = 0.5677300563596626 Acc = 0.7
# --- Fold 51 started at Thu Apr 25 11:43:19 2019
# TN = 9 FN = 11 FP = 9 TP = 21
# AUC =  0.6163194444444444 Loss = 0.6991508445560711 Acc = 0.6
# --- Fold 52 started at Thu Apr 25 11:43:20 2019
# TN = 12 FN = 11 FP = 6 TP = 21
# AUC =  0.7708333333333334 Loss = 0.5623460640732969 Acc = 0.66
# --- Fold 53 started at Thu Apr 25 11:43:20 2019
# TN = 11 FN = 4 FP = 7 TP = 28
# AUC =  0.8333333333333334 Loss = 0.5073392743048354 Acc = 0.78
# --- Fold 54 started at Thu Apr 25 11:43:20 2019
# TN = 12 FN = 2 FP = 6 TP = 30
# AUC =  0.8680555555555555 Loss = 0.4619083744963588 Acc = 0.84
# --- Fold 55 started at Thu Apr 25 11:43:20 2019
# TN = 8 FN = 4 FP = 10 TP = 28
# AUC =  0.7430555555555556 Loss = 0.5657011926628711 Acc = 0.72
# --- Fold 56 started at Thu Apr 25 11:43:20 2019
# TN = 12 FN = 4 FP = 6 TP = 28
# AUC =  0.8784722222222222 Loss = 0.424486947999455 Acc = 0.8
# --- Fold 57 started at Thu Apr 25 11:43:21 2019
# TN = 9 FN = 8 FP = 9 TP = 24
# AUC =  0.7482638888888888 Loss = 0.5794022455223743 Acc = 0.66
# --- Fold 58 started at Thu Apr 25 11:43:21 2019
# TN = 11 FN = 8 FP = 7 TP = 24
# AUC =  0.7760416666666667 Loss = 0.5567683249998926 Acc = 0.7
# --- Fold 59 started at Thu Apr 25 11:43:21 2019
# TN = 13 FN = 15 FP = 5 TP = 17
# AUC =  0.734375 Loss = 0.6204848965399103 Acc = 0.6
# --- Fold 60 started at Thu Apr 25 11:43:21 2019
# TN = 10 FN = 7 FP = 8 TP = 25
# AUC =  0.7482638888888888 Loss = 0.5656277824409117 Acc = 0.7
# --- Fold 61 started at Thu Apr 25 11:43:21 2019
# TN = 13 FN = 10 FP = 5 TP = 22
# AUC =  0.7291666666666667 Loss = 0.57680817166554 Acc = 0.7
# --- Fold 62 started at Thu Apr 25 11:43:22 2019
# TN = 12 FN = 7 FP = 6 TP = 25
# AUC =  0.828125 Loss = 0.4815990190253265 Acc = 0.74
# --- Fold 63 started at Thu Apr 25 11:43:22 2019
# TN = 11 FN = 4 FP = 7 TP = 28
# AUC =  0.795138888888889 Loss = 0.5398418800202718 Acc = 0.78
# --- Fold 64 started at Thu Apr 25 11:43:22 2019
# TN = 13 FN = 9 FP = 5 TP = 23
# AUC =  0.795138888888889 Loss = 0.5582965902239816 Acc = 0.72
# --- Fold 65 started at Thu Apr 25 11:43:22 2019
# TN = 12 FN = 7 FP = 6 TP = 25
# AUC =  0.7777777777777777 Loss = 0.5193758780807347 Acc = 0.74
# --- Fold 66 started at Thu Apr 25 11:43:22 2019
# TN = 10 FN = 9 FP = 8 TP = 23
# AUC =  0.704861111111111 Loss = 0.6264949443554173 Acc = 0.66
# --- Fold 67 started at Thu Apr 25 11:43:23 2019
# TN = 11 FN = 8 FP = 7 TP = 24
# AUC =  0.7725694444444444 Loss = 0.5333590182208797 Acc = 0.7
# --- Fold 68 started at Thu Apr 25 11:43:23 2019
# TN = 11 FN = 6 FP = 7 TP = 26
# AUC =  0.782986111111111 Loss = 0.5559345743615179 Acc = 0.74
# --- Fold 69 started at Thu Apr 25 11:43:23 2019
# TN = 12 FN = 10 FP = 6 TP = 22
# AUC =  0.751736111111111 Loss = 0.5947821129709432 Acc = 0.68
# --- Fold 70 started at Thu Apr 25 11:43:23 2019
# TN = 13 FN = 6 FP = 5 TP = 26
# AUC =  0.7777777777777777 Loss = 0.5431661961251563 Acc = 0.78
# --- Fold 71 started at Thu Apr 25 11:43:23 2019
# TN = 15 FN = 8 FP = 3 TP = 24
# AUC =  0.8524305555555555 Loss = 0.4848537327646443 Acc = 0.78
# --- Fold 72 started at Thu Apr 25 11:43:24 2019
# TN = 13 FN = 8 FP = 5 TP = 24
# AUC =  0.8072916666666666 Loss = 0.5405569876839463 Acc = 0.74
# --- Fold 73 started at Thu Apr 25 11:43:24 2019
# TN = 14 FN = 10 FP = 4 TP = 22
# AUC =  0.7934027777777778 Loss = 0.5523040895047976 Acc = 0.72
# --- Fold 74 started at Thu Apr 25 11:43:24 2019
# TN = 7 FN = 3 FP = 11 TP = 29
# AUC =  0.7013888888888888 Loss = 0.6021271499988071 Acc = 0.72
# --- Fold 75 started at Thu Apr 25 11:43:24 2019
# TN = 9 FN = 6 FP = 9 TP = 26
# AUC =  0.8402777777777778 Loss = 0.4677651428586683 Acc = 0.7
# --- Fold 76 started at Thu Apr 25 11:43:24 2019
# TN = 12 FN = 10 FP = 6 TP = 22
# AUC =  0.8072916666666667 Loss = 0.5168623681749935 Acc = 0.68
# --- Fold 77 started at Thu Apr 25 11:43:25 2019
# TN = 12 FN = 5 FP = 6 TP = 27
# AUC =  0.890625 Loss = 0.43879939594152195 Acc = 0.78
# --- Fold 78 started at Thu Apr 25 11:43:25 2019
# TN = 15 FN = 11 FP = 3 TP = 21
# AUC =  0.7881944444444444 Loss = 0.5762609102941538 Acc = 0.72
# --- Fold 79 started at Thu Apr 25 11:43:25 2019
# TN = 12 FN = 8 FP = 6 TP = 24
# AUC =  0.7430555555555555 Loss = 0.5861353337100152 Acc = 0.72
# --- Fold 80 started at Thu Apr 25 11:43:25 2019
# TN = 11 FN = 6 FP = 7 TP = 26
# AUC =  0.7760416666666666 Loss = 0.5515807813926369 Acc = 0.74
# --- Fold 81 started at Thu Apr 25 11:43:25 2019
# TN = 9 FN = 10 FP = 9 TP = 22
# AUC =  0.7065972222222222 Loss = 0.5955383641179445 Acc = 0.62
# --- Fold 82 started at Thu Apr 25 11:43:26 2019
# TN = 10 FN = 5 FP = 8 TP = 27
# AUC =  0.7690972222222222 Loss = 0.5365460544609706 Acc = 0.74
# --- Fold 83 started at Thu Apr 25 11:43:26 2019
# TN = 13 FN = 11 FP = 5 TP = 21
# AUC =  0.795138888888889 Loss = 0.5679767341361364 Acc = 0.68
# --- Fold 84 started at Thu Apr 25 11:43:26 2019
# TN = 8 FN = 4 FP = 10 TP = 28
# AUC =  0.7916666666666666 Loss = 0.5275794788765945 Acc = 0.72
# --- Fold 85 started at Thu Apr 25 11:43:26 2019
# TN = 13 FN = 10 FP = 5 TP = 22
# AUC =  0.7413194444444444 Loss = 0.6066691058974408 Acc = 0.7
# --- Fold 86 started at Thu Apr 25 11:43:26 2019
# TN = 10 FN = 6 FP = 8 TP = 26
# AUC =  0.7847222222222222 Loss = 0.5353843034462666 Acc = 0.72
# --- Fold 87 started at Thu Apr 25 11:43:27 2019
# TN = 14 FN = 9 FP = 4 TP = 23
# AUC =  0.814236111111111 Loss = 0.5122781629137256 Acc = 0.74
# --- Fold 88 started at Thu Apr 25 11:43:27 2019
# TN = 11 FN = 6 FP = 7 TP = 26
# AUC =  0.8072916666666666 Loss = 0.501480921502377 Acc = 0.74
# --- Fold 89 started at Thu Apr 25 11:43:27 2019
# TN = 12 FN = 9 FP = 6 TP = 23
# AUC =  0.7934027777777778 Loss = 0.5265971715332843 Acc = 0.7
# --- Fold 90 started at Thu Apr 25 11:43:27 2019
# TN = 14 FN = 9 FP = 4 TP = 23
# AUC =  0.7708333333333333 Loss = 0.559995788036559 Acc = 0.74
# --- Fold 91 started at Thu Apr 25 11:43:27 2019
# TN = 11 FN = 7 FP = 7 TP = 25
# AUC =  0.6996527777777778 Loss = 0.6403641838900168 Acc = 0.72
# --- Fold 92 started at Thu Apr 25 11:43:28 2019
# TN = 8 FN = 6 FP = 10 TP = 26
# AUC =  0.7760416666666666 Loss = 0.5320173959182042 Acc = 0.68
# --- Fold 93 started at Thu Apr 25 11:43:28 2019
# TN = 11 FN = 5 FP = 7 TP = 27
# AUC =  0.8298611111111112 Loss = 0.5062417508393269 Acc = 0.76
# --- Fold 94 started at Thu Apr 25 11:43:28 2019
# TN = 9 FN = 4 FP = 9 TP = 28
# AUC =  0.8454861111111112 Loss = 0.46990534101198583 Acc = 0.74
# --- Fold 95 started at Thu Apr 25 11:43:28 2019
# TN = 11 FN = 9 FP = 7 TP = 23
# AUC =  0.732638888888889 Loss = 0.5936982452207157 Acc = 0.68
# --- Fold 96 started at Thu Apr 25 11:43:28 2019
# TN = 9 FN = 9 FP = 9 TP = 23
# AUC =  0.6770833333333334 Loss = 0.624279473288654 Acc = 0.64
# --- Fold 97 started at Thu Apr 25 11:43:29 2019
# TN = 13 FN = 5 FP = 5 TP = 27
# AUC =  0.8871527777777778 Loss = 0.45939765727683207 Acc = 0.8
# --- Fold 98 started at Thu Apr 25 11:43:29 2019
# TN = 15 FN = 5 FP = 3 TP = 27
# AUC =  0.8802083333333333 Loss = 0.4737509456132976 Acc = 0.84
# --- Fold 99 started at Thu Apr 25 11:43:29 2019
# TN = 9 FN = 5 FP = 9 TP = 27
# AUC =  0.8229166666666667 Loss = 0.4745117245591419 Acc = 0.72

# %%
predict = pd.DataFrame()
i = 0
for model in models:
    predict[i] = model.predict_proba(test_df)[:,1]
    i += 1
predictions = predict.mean(axis=1)

# %%
predictions
# Out:
# 0        0.641045
# 1        0.395032
# 2        0.725760
# 3        0.804511
# 4        0.718820
# 5        0.373126
# 6        0.226903
# 7        0.174661
# 8        0.664140
# 9        0.132114
# 10       0.728307
# 11       0.447155
# 12       0.527075
# 13       0.489219
# 14       0.304647
# 15       0.732668
# 16       0.554350
# 17       0.718524
# 18       0.679486
# 19       0.405016
# 20       0.473495
# 21       0.649419
# 22       0.467863
# 23       0.557912
# 24       0.326506
# 25       0.556473
# 26       0.048270
# 27       0.855978
# 28       0.686605
# 29       0.667381
#            ...
# 19720    0.365093
# 19721    0.916168
# 19722    0.630523
# 19723    0.114699
# 19724    0.744705
# 19725    0.607666
# 19726    0.879052
# 19727    0.632335
# 19728    0.577922
# 19729    0.893650
# 19730    0.373457
# 19731    0.178191
# 19732    0.758980
# 19733    0.384564
# 19734    0.775695
# 19735    0.403274
# 19736    0.744211
# 19737    0.735188
# 19738    0.843716
# 19739    0.622005
# 19740    0.678477
# 19741    0.706220
# 19742    0.372368
# 19743    0.112050
# 19744    0.838712
# 19745    0.580887
# 19746    0.977858
# 19747    0.438969
# 19748    0.901499
# 19749    0.137841
# Length: 19750, dtype: float64

# %%
sub = pd.read_csv("data/sample_submission.csv")
print(predictions.shape)
print(sub.shape)
sub['target'] = predictions
sub.to_csv("results/submit_results.csv", index=False)
print('done')
# Out:
# (19750,)
# (19750, 2)
# done
